# %%
pip install tensorflow keras matplotlib numpy
# Out:
# ...
#
#   Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os

# %%
import os
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define dataset path
dataset_path = r"D:\\cattle diseases.dataset"
train_csv = os.path.join(dataset_path, "train", "train_labels.csv")
valid_csv = os.path.join(dataset_path, "valid", "valid_labels.csv")
test_csv = os.path.join(dataset_path, "test", "test_labels.csv")

train_dir = os.path.join(dataset_path, "train")
valid_dir = os.path.join(dataset_path, "valid")
test_dir = os.path.join(dataset_path, "test")

# Load CSV files
train_df = pd.read_csv(train_csv)
valid_df = pd.read_csv(valid_csv)
test_df = pd.read_csv(test_csv)

# %%
# Ensure file paths are correct
train_df["filename"] = train_df["filename"].apply(lambda x: os.path.join(train_dir, x))
valid_df["filename"] = valid_df["filename"].apply(lambda x: os.path.join(valid_dir, x))
test_df["filename"] = test_df["filename"].apply(lambda x: os.path.join(test_dir, x))

# Select label columns (exclude filename)
label_columns = train_df.columns[1:]  # All columns except 'filename'

# Convert labels to a NumPy array for multi-label classification
train_df[label_columns] = train_df[label_columns].astype(float)
valid_df[label_columns] = valid_df[label_columns].astype(float)
test_df[label_columns] = test_df[label_columns].astype(float)

# Image preprocessing
IMG_SIZE = (150, 150)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators using flow_from_dataframe() for multi-label classification
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col="filename",  
    y_col=label_columns.tolist(),  # Multi-labels
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw"  # Important for multi-label classification
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col="filename",
    y_col=label_columns.tolist(),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw"
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col="filename",
    y_col=label_columns.tolist(),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw"
)

# Print number of classes (labels)
num_classes = len(label_columns)
print(f"Number of classes: {num_classes}")
# Out:
# Found 567 validated image filenames.
# Found 186 validated image filenames.
# Found 81 validated image filenames.
# Number of classes: 11

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Build CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    
    Dense(num_classes, activation='sigmoid')  # Multi-label classification
])

# Compile the model
model.compile(
    loss='binary_crossentropy',  # Use binary cross-entropy for multi-label
    optimizer='adam',
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# C:\Users\DELL\OneDrive\Desktop\Dairy_Care_System\env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping

EPOCHS = 10  # Adjust as needed

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=EPOCHS,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 500ms/step - accuracy: 0.7121 - loss: 0.0640 - val_accuracy: 0.7366 - val_loss: 0.2577
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 483ms/step - accuracy: 0.7168 - loss: 0.0532 - val_accuracy: 0.8118 - val_loss: 0.3380
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 483ms/step - accuracy: 0.7628 - loss: 0.0296 - val_accuracy: 0.8172 - val_loss: 0.2844
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 495ms/step - accuracy: 0.7873 - loss: 0.0487 - val_accuracy: 0.8011 - val_loss: 0.3056
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 485ms/step - accuracy: 0.7726 - loss: 0.0408 - val_accuracy: 0.8172 - val_loss: 0.2958
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 497ms/step - accuracy: 0.7686 - loss: 0.0283 - val_accuracy: 0.6720 - val_loss: 0.3525
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 498ms/step - accuracy: 0.7448 - loss: 0.0149 - val_accuracy: 0.5054 - val_loss: 0.3897
# Epoch 8/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - accuracy: 0.9177 - loss: 0.0415
# Test Accuracy: 91.36%

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model.save("cattle_disease_model.keras")
